# %% [markdown]
# <a href="https://colab.research.google.com/github/mahanthianuradha/Player-score-calculator/blob/master/Leakage_%26_Imbalance_cars_messy_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task 1 — Explore and Identify Issues

# %%
import pandas as pd
import numpy as np

# %%
url = "https://drive.google.com/uc?export=download&id=14Yxdyp_vTM94nBjNH2igpsfjvMgbefWO"

df = pd.read_csv(url)
df
# Out:
#        Unnamed: 0          car_name       brand    model  vehicle_age  \
# 0            2581    Renault Duster     Renault   Duster            7
# 1             224    Maruti Wagon R      Maruti  Wagon R            3
# 2            1803        Honda City       Honda     City            3
# 3            2728  Mahindra Scorpio    Mahindra  Scorpio            6
# 4           14160   Mahindra XUV500    Mahindra   XUV500            4
# ...           ...               ...         ...      ...          ...
# 15656        6581     Maruti Ertiga      Maruti   Ertiga            7
# 15657       17029  Volkswagen Vento  Volkswagen    Vento           11
# 15658        6839    Maruti Wagon R      Maruti  Wagon R            7
# 15659        1104       Hyundai i20     Hyundai      i20            2
# 15660        9295       Maruti Ciaz      Maruti     Ciaz            2
#
#       km_driven seller_type fuel_type transmission_type mileage  engine  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15661 entries, 0 to 15660
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         15661 non-null  int64
#  1   car_name           15661 non-null  object
#  2   brand              15661 non-null  object
#  3   model              15661 non-null  object
#  4   vehicle_age        15661 non-null  int64
#  5   km_driven          15661 non-null  object
#  6   seller_type        15661 non-null  object
#  7   fuel_type          15661 non-null  object
#  8   transmission_type  15661 non-null  object
#  9   mileage            14376 non-null  object
#  10  engine             13792 non-null  float64
#  11  max_power          14862 non-null  float64
#  12  seats              15218 non-null  float64
#  13  selling_price      15503 non-null  float64
# dtypes: float64(4), int64(2), object(8)
# memory usage: 1.7+ MB
# (15661, 14)

# %%
df.shape
# Out:
# (15661, 14)

# %%
df.describe()
# Out:
#          Unnamed: 0   vehicle_age        engine     max_power         seats  \
# count  15661.000000  15661.000000  13792.000000  14862.000000  15218.000000
# mean    9808.189643      6.036843   1480.489342    100.513582      5.324418
# std     5642.981540      3.015072    511.446057     42.854632      0.805993
# min        0.000000      0.000000    793.000000     38.400000      0.000000
# 25%     4901.000000      4.000000   1197.000000     74.000000      5.000000
# 50%     9858.000000      6.000000   1248.000000     88.500000      5.000000
# 75%    14666.000000      8.000000   1582.000000    117.300000      5.000000
# max    19543.000000     29.000000   6592.000000    626.000000      9.000000
#
#        selling_price
# count   1.550300e+04
# mean    1.032764e+06
# std     1.607380e+07
# min     5.000000e+02
# 25%     3.850000e+05
# 50%     5.550000e+05
# 75%     8.250000e+05
# max     1.000000e+09

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# car_name                0
# brand                   0
# model                   0
# vehicle_age             0
# km_driven               0
# seller_type             0
# fuel_type               0
# transmission_type       0
# mileage              1285
# engine               1869
# max_power             799
# seats                 443
# selling_price         158
# dtype: int64

# %% [markdown]
# Observations :
# 1.kilometers driven and mileage given as object.
# 2.min and max car price are also need to check because those are abnormal.
# 3.And also the min nummber of car seats is zero which is impossible.
# 4.column Unnamed  = 0 which is not useful.

# %% [markdown]
# Task 2 — Clean the Data
# Fix the issues identified:
# drop null target rows, impute missing input features, strip and lowercase the brand column, extract numeric values from the mileage column, and remove duplicates.

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'car_name', 'brand', 'model', 'vehicle_age', 'km_driven',
#        'seller_type', 'fuel_type', 'transmission_type', 'mileage', 'engine',
#        'max_power', 'seats', 'selling_price'],
#       dtype='object')

# %%
df = df.drop(columns=['Unnamed: 0'])
df.head(10)
# Out:
#              car_name     brand        model  vehicle_age km_driven  \
# 0      Renault Duster   Renault       Duster            7     67647
# 1      Maruti Wagon R    Maruti      Wagon R            3     52000
# 2          Honda City     Honda         City            3     48959
# 3    Mahindra Scorpio  Mahindra      Scorpio            6     82000
# 4     Mahindra XUV500  Mahindra       XUV500            4     34000
# 5         Hyundai i10   Hyundai          i10           12     73000
# 6         Hyundai i20   Hyundai          i20           12     88000
# 7      Maruti Wagon R    Maruti      Wagon R            7     50000
# 8      Ford Freestyle      Ford    Freestyle            2     30000
# 9  Maruti Swift Dzire    Maruti  Swift Dzire           10     75220
#
#   seller_type fuel_type transmission_type mileage  engine  max_power  seats  \
# 0      Dealer    Diesel            Manual   19.87  1461.0      83.80    5.0
# ...

# %%
df = df.dropna(subset = ['selling_price'])
df
# Out:
#                car_name       brand    model  vehicle_age km_driven  \
# 0        Renault Duster     Renault   Duster            7     67647
# 1        Maruti Wagon R      Maruti  Wagon R            3     52000
# 2            Honda City       Honda     City            3     48959
# 3      Mahindra Scorpio    Mahindra  Scorpio            6     82000
# 4       Mahindra XUV500    Mahindra   XUV500            4     34000
# ...                 ...         ...      ...          ...       ...
# 15656     Maruti Ertiga      Maruti   Ertiga            7    127731
# 15657  Volkswagen Vento  Volkswagen    Vento           11     59000
# 15658    Maruti Wagon R      Maruti  Wagon R            7     20000
# 15659       Hyundai i20     Hyundai      i20            2     15000
# 15660       Maruti Ciaz      Maruti     Ciaz            2     30000
#
#       seller_type fuel_type transmission_type mileage  engine  max_power  \
# 0          Dealer    Diesel            Manual   19.87  1461.0      83.80
# ...

# %%
df.isnull().sum()
# Out:
# car_name                0
# brand                   0
# model                   0
# vehicle_age             0
# km_driven               0
# seller_type             0
# fuel_type               0
# transmission_type       0
# mileage              1269
# engine               1852
# max_power             791
# seats                 438
# selling_price           0
# dtype: int64

# %% [markdown]
#  Impute missing input features

# %%
#extract numeric values from the mileage column
df['mileage'] = df['mileage'].astype(str).str.replace('kmpl', '').str.replace('kmp', '').str.strip()

df['mileage'] = pd.to_numeric(df['mileage'], errors='coerce')
df['mileage'].head()
# Out:
# 0    19.87
# 1    33.54
# 2      NaN
# 3    15.40
# 4    16.00
# Name: mileage, dtype: float64

# %%
# impute missing input features:
for col in ['engine', 'mileage', 'max_power']:
    median_val = df[col].median()
    df[col] = df[col].fillna(median_val)
    print(f"Filled {col} missing values with median: {median_val}")
# Out:
# Filled engine missing values with median: 1248.0
# Filled mileage missing values with median: 19.67
# Filled max_power missing values with median: 88.5

# %%
seats_mode = df['seats'].mode()[0]
df['seats'] = df['seats'].fillna(seats_mode)
print(f"Filled seats missing values with mode: {seats_mode}")
# Out:
# Filled seats missing values with mode: 5.0

# %%
df.isnull().sum()
# Out:
# car_name             0
# brand                0
# model                0
# vehicle_age          0
# km_driven            0
# seller_type          0
# fuel_type            0
# transmission_type    0
# mileage              0
# engine               0
# max_power            0
# seats                0
# selling_price        0
# dtype: int64

# %%
#remove duplicates:
cat_cols = ['car_name', 'brand', 'seller_type', 'fuel_type', 'transmission_type']

for col in cat_cols:
    unique_vals = df[col].unique()
    print(f"\n{col} {len(unique_vals)} unique values): ")
    print(sorted(unique_vals))
# Out:
# car_name 121 unique values):
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(261)

# %%
df = df.drop_duplicates()
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#         vehicle_age       mileage        engine     max_power         seats  \
# count  15242.000000  15242.000000  15242.000000  15242.000000  15242.000000
# mean       6.037659     19.692756   1452.969623     99.982870      5.314526
# std        3.016265      4.002252    486.344414     41.947384      0.796545
# min        0.000000      4.000000    793.000000     38.400000      0.000000
# 25%        4.000000     17.092500   1197.000000     74.000000      5.000000
# 50%        6.000000     19.670000   1248.000000     88.500000      5.000000
# 75%        8.000000     22.320000   1498.000000    113.415000      5.000000
# max       29.000000     33.540000   6592.000000    626.000000      9.000000
#
#        selling_price
# count   1.524200e+04
# mean    1.037976e+06
# std     1.621050e+07
# min     5.000000e+02
# 25%     3.850000e+05
# 50%     5.550000e+05
# 75%     8.250000e+05
# max     1.000000e+09
